# %% [markdown]
# ##### Converting the tokens or corpus to vectors

# %% [markdown]
# #### Word - Embeddings

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 import pandas as pd
#
# File d:\Hackathon\venv\Lib\site-packages\pandas\__init__.py:62
#      59 # let init-time option registration happen
#      60 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 62 from pandas.core.api import (
#      63     # dtype
#      64     ArrowDtype,
#      65     Int8Dtype,
#      66     Int16Dtype,
#      67     Int32Dtype,
#      68     Int64Dtype,
#      69     UInt8Dtype,
#      70     UInt16Dtype,
#      71     UInt32Dtype,
#      72     UInt64Dtype,
#      73     Float32Dtype,
#      74     Float64Dtype,
#      75     CategoricalDtype,
#      76     PeriodDtype,
#      77     IntervalDtype,
#      78     DatetimeTZDtype,
#      79     StringDtype,
#      80     BooleanDtype,
#      81     # missing
#      82     NA,
# ...

# %%
df= pd.read_csv('processed_train.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df= pd.read_csv('processed_train.csv')
#
# NameError: name 'pd' is not defined

# %%
df
# Out:
#        Unnamed: 0                               category  \
# 0               0  Online and Social Media Related Crime
# 1               1                 Online Financial Fraud
# 2               2               Online Gambling  Betting
# 3               3  Online and Social Media Related Crime
# 4               4                 Online Financial Fraud
# ...           ...                                    ...
# 92436       93681                 Online Financial Fraud
# 92437       93682                 Online Financial Fraud
# 92438       93683                 Online Financial Fraud
# 92439       93684  Online and Social Media Related Crime
# 92440       93685                 Online Financial Fraud
#
#                             sub_category  \
# 0      Cyber Bullying  Stalking  Sexting
# 1                      Fraud CallVishing
# 2               Online Gambling  Betting
# 3                       Online Job Fraud
# 4                      Fraud CallVishing
# ...

# %%
df['category_subcategory'] = df['category'] + ' - ' + df['sub_category']

print(df[['category_subcategory', 'processed_info']].head())
# Out:
#                                 category_subcategory  \
# 0  Online and Social Media Related Crime - Cyber ...
# 1         Online Financial Fraud - Fraud CallVishing
# 2  Online Gambling  Betting - Online Gambling  Be...
# 3  Online and Social Media Related Crime - Online...
# 4         Online Financial Fraud - Fraud CallVishing
#
#                                       processed_info
# 0  ['continue', 'receive', 'random', 'call', 'abu...
# 1  ['fraudster', 'continuously', 'message', 'ask'...
# 2  ['act', 'like', 'police', 'demanding', 'money'...
# 3  ['apna', 'job', 'apply', 'job', 'interview', '...
# 4  ['receive', 'call', 'lady', 'state', 'send', '...

# %%
df1=df.drop(columns=['category','sub_category'])

# %%
df1
# Out:
#        Unnamed: 0                                     processed_info  \
# 0               0  ['continue', 'receive', 'random', 'call', 'abu...
# 1               1  ['fraudster', 'continuously', 'message', 'ask'...
# 2               2  ['act', 'like', 'police', 'demanding', 'money'...
# 3               3  ['apna', 'job', 'apply', 'job', 'interview', '...
# 4               4  ['receive', 'call', 'lady', 'state', 'send', '...
# ...           ...                                                ...
# 92436       93681  ['identity', 'theft', 'smishing', 'sms', 'frau...
# 92437       93682  ['receive', 'call', 'number', 'ask', 'phone', ...
# 92438       93683  ['cyber', 'stalk', 'blackmail', 'phonesmsvoip'...
# 92439       93684  ['call', 'karke', 'bola', 'ki', 'aapka', 'lota...
# 92440       93685  ['app', 'name', 'koko', 'loan', 'app', 'send',...
#
#                                     category_subcategory
# 0      Online and Social Media Related Crime - Cyber ...
# ...
